# %% [markdown]
# # CHAPTER 7  - `Files`

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd drive/MyDrive/MAMA
# Out:
# /content/drive/MyDrive/MAMA

# %%
# %cd ColabNotebooks/MAMA/
# Out:
# [Errno 2] No such file or directory: 'ColabNotebooks/MAMA/'
# /content/drive/MyDrive/MAMA

# %%
file_handle = open('MAMA.txt', 'r')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='MAMA.txt' mode='r' encoding='UTF-8'>

# %%
f = open('MAMA.txt')
for line in f:
  print(line.upper())
# Out:
# MAMA
#
#
#
# MARY
#
#
#
# PALMS

# %% [markdown]
# #### Exercise 2

# %%
f = open('MAMA.txt')
lines = f.readlines()
print(len(lines))
# Out:
# 5

# %%
try:
  filename = 'MAMA.txt'
  with open(filename) as file:
    lines = file.readlines()
    print('{} has {} lines.'.format(filename, len(lines)))
except:
    print(filename+ 'does not exist.')
# Out:
# MAMA.txt has 5 lines.

# %% [markdown]
# ## CHALLENGE

# %%
filename = input('Enter a filename: ')

try:
  with open(filename, ' r') as f:
    for line in f:
      if 'Gara' in line:
        line = line.rscript()
        print(line)

except:
  print(filename+ ' does not exist.')
# Out:
# Enter a filename: MAMA.txt
# MAMA.txt does not exist.
