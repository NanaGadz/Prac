# %% [markdown]
# # CHAPTER 6  - `Strings`

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %%
text = 'Business Analytics'
text[4]
text[2:4]
text[:4]
text[4:]
text[-2]
text[-4:-2]
text[-2:]
text[:-2]
# Out:
# 'Business Analyti'

# %% [markdown]
# #### Exercise 2

# %%
phrase = 'One Ring to rule them all'
'One '
'Ring'
'all'
'them'
'One Ring to rule them all'
# Out:
# 'One Ring to rule them all'

# %% [markdown]
# ## CHALLENGE

# %%
while True:
  full_name = input("Enter a full name: (or type 'exit'):")

  if full_name.lower() == 'exit':
    break

  formatted_name = full_name.strip().capitalize()

  print("Formatted Name:", formatted_name)
# Out:
# Enter a full name: (or type 'exit'):Grace Opao
# Formatted Name: Grace opao
# Enter a full name: (or type 'exit'):exit
